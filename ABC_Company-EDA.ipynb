# %% [markdown]
# ABC Company
#  Dataset from ABC company, consisting of 458 rows and 9 columns. The company requires a comprehensive report detailing information about their employees across various teams.For that  preprocessing the dataset, analyzing the data, and have to find insights.
#
#  Step1: Import relevant modules
#  step2: Data load as csv file
#  step3: Data Cleaning and preprocess

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df=pd.read_csv("college.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include='all')
# Out:
#             Name                  Team      Number Position         Age  \
# count        458                   458  458.000000      458  458.000000
# unique       458                    30         NaN        5         NaN
# top     Priyanka  New Orleans Pelicans         NaN       SG         NaN
# freq           1                    19         NaN      102         NaN
# mean         NaN                   NaN   17.713974      NaN   26.934498
# std          NaN                   NaN   15.966837      NaN    4.400128
# min          NaN                   NaN    0.000000      NaN   19.000000
# 25%          NaN                   NaN    5.000000      NaN   24.000000
# 50%          NaN                   NaN   13.000000      NaN   26.000000
# 75%          NaN                   NaN   25.000000      NaN   30.000000
# max          NaN                   NaN   99.000000      NaN   40.000000
#
#         Height      Weight   College        Salary
# count      458  458.000000       374  4.470000e+02
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
#To check if there are any duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.shape)
# Out:
# (458, 9)

# %%
# Replace 'Height' column with random numbers between 150 and 180
df['Height'] = np.random.randint(150, 181, df.shape[0])

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2   John Holland  Boston Celtics      30       SG   27     154     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     167     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %%
sns.boxplot(data=df[['Age', 'Height', 'Weight', 'Salary']])
# Add title and labels
plt.title('Boxplot for Salary to Detect Outliers')
plt.xlabel('Salary')
plt.show()

# %%
df['Salary'].fillna(df['Salary'].median(), inplace=True)
# Out:
# C:\Users\RAMEESHA\AppData\Local\Temp\ipykernel_16900\2984858743.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Salary'].fillna(df['Salary'].median(), inplace=True)

# %%
print(df.isnull().sum())
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %%
print(df.isnull().sum())
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary       0
# dtype: int64

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     164     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2   John Holland  Boston Celtics      30       SG   27     178     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     157     185
# 6  Jordan Mickey  Boston Celtics      55       PF   21     167     235
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University  2836186.0
# 3      Georgia State  1148640.0
# 6                LSU  1170960.0

# %%
df['College'].fillna('Unknown', inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     154     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     167     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     172     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     179     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     177     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Distribution of employees across teams
team_distribution = df['Team'].value_counts()
team_percentage = (team_distribution / len(df)) * 100

print(team_distribution)
print(team_percentage)
# Out:
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# Utah Jazz                 16
# Milwaukee Bucks           16
# New York Knicks           16
# Boston Celtics            15
# Los Angeles Clippers      15
# Los Angeles Lakers        15
# Phoenix Suns              15
# Sacramento Kings          15
# Brooklyn Nets             15
# Philadelphia 76ers        15
# Toronto Raptors           15
# Golden State Warriors     15
# Indiana Pacers            15
# Detroit Pistons           15
# Cleveland Cavaliers       15
# Chicago Bulls             15
# Houston Rockets           15
# San Antonio Spurs         15
# Atlanta Hawks             15
# Dallas Mavericks          15
# Charlotte Hornets         15
# Miami Heat                15
# Denver Nuggets            15
# Washington Wizards        15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Orlando Magic             14
# Minnesota Timberwolves    14
# Name: count, dtype: int64
# Team
# ...

# %%
plt.figure(figsize=(10, 6))
team_percentage.plot(kind='bar', color='skyblue')
plt.title('Percentage Distribution of Employees by Team')
plt.ylabel('Percentage (%)')
plt.xlabel('Teams')
plt.show()

# %% [markdown]
# Insight:
# The New Orleans Pelicans lead with the highest percentage of employees, suggesting a larger team size relative to others.
# The Minnesota Timberwolves and Orlando Magic are at the lower end with the smallest percentage of employees.

# %%
# 2 Distribution of employees by position
position_distribution = df['Position'].value_counts()
print(position_distribution)
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
# Horizontal Bar Chart
plt.figure(figsize=(10, 6))
sns.barplot(x=position_distribution.values, y=position_distribution.index, palette='viridis')
plt.title('Distribution of Employees by Position')
plt.xlabel('Number of Employees')
plt.ylabel('Position')
plt.show()
# Out:
# C:\Users\RAMEESHA\AppData\Local\Temp\ipykernel_17392\4067597674.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=position_distribution.values, y=position_distribution.index, palette='viridis')

# %%
# Age group distribution
age_bins = [20, 25, 30, 35, 40, 50]
age_labels = ['20-25', '25-30', '30-35', '35-40', '40+']
df['Age Group'] = pd.cut(df['Age'], bins=age_bins, labels=age_labels, right=False)

age_group_distribution = df['Age Group'].value_counts()
print(age_group_distribution)
# Out:
# Age Group
# 25-30    182
# 20-25    152
# 30-35     90
# 35-40     29
# 40+        3
# Name: count, dtype: int64

# %%
# Define age bins and labels
bins = [15, 20, 25, 30, 35, 40]
labels = ['15-20', '21-25', '26-30', '31-35', '36-40']

# Create a new column 'Age Group'
df['Age Group'] = pd.cut(df['Age'], bins=bins, labels=labels, right=False)

plt.figure(figsize=(8, 6))
sns.histplot(df['Age Group'], discrete=True)

# Adding labels and title
plt.title('Age Group Distribution')
plt.xlabel('Age Group')
plt.ylabel('Frequency')

# Display the plot
plt.show()

# %%
salary_by_team_position = df.groupby(['Team', 'Position'])['Salary'].sum()
highest_salary_team_position = salary_by_team_position.idxmax()
print(highest_salary_team_position)
print(salary_by_team_position.max())
# Out:
# ('Los Angeles Lakers', 'SF')
# 31866445.0

# %%
df1 = df.pivot_table(index='Position', columns='Team', values='Salary')
plt.figure(figsize=(8, 6))
sns.heatmap(df1, annot=True, fmt=".0f", cmap='YlGnBu', linewidths=.5)
plt.title('Team and Position Salary Expenditure')
plt.xlabel('Team')
plt.ylabel('Position')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Correlation between age and salary
correlation = df['Age'].corr(df['Salary'])
print(f'Correlation between Age and Salary: {correlation}')

# Visualize with a scatter plot
sns.scatterplot(x='Age', y='Salary', data=df)
plt.title('Age vs. Salary')
plt.show()
# Out:
# Correlation between Age and Salary: 0.2140094122657097

# %%
# Plot a pie chart
import pandas as pd
import matplotlib.pyplot as plt
position_distribution = df['Position'].value_counts()
plt.figure(figsize=(8, 8))
plt.pie(position_distribution, labels=position_distribution.index, autopct='%1.1f%%', startangle=140, colors=plt.get_cmap('Set2').colors)
plt.title('Position Distribution')
plt.show()

# %%
corr_matrix = df[['Age', 'Salary']].corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap: Age and Salary')
plt.show()

# %%
df['College'].fillna('Unknown', inplace=True)

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     169     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     172     235
# 2     John Holland  Boston Celtics      30       SG   27     154     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     167     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     177     203
# 454      Raul Neto       Utah Jazz      25       PG   24     172     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     179     256
# 456    Jeff Withey       Utah Jazz      24        C   26     150     231
# 457       Priyanka       Utah Jazz      34        C   25     177     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...
